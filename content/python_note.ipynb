# %% [markdown]
# # Python Note
# requirements Modules:
# numpy scikit-learn matplotlib pandas textblob
# Numpy: A library with functions to operate on n-dimensional arrays and matrices.
# Scikit-learn: A hightly advanced module for machine learning. It contains a good number of algorithms for classification, regression, and clustering, among others.
# Matplotlib: Plotting Library that makes use of NumPy to graph a good variety of charts, including line plots, histograms, scatter plots, and even 3D graphs.
# Pandas: This Libarary deals with data manipulation and analysis
# ```
#     import matplotlib.pyplot as plt
#     import math
#     x=list(range(1,100))
#     plot.plot(x,[math.log(y,2) for y in x]) #O(log n)
#     plot.plot(x,[y for y in x])  #O(n)
#     plot.plot(x,[y*math.log(y,2) for y in x]) #O(n log n)
# ```
# ###### Floating Error

# %%
1-0.9
# Out:
# 0.09999999999999998

# %%
import matplotlib.pyplot as plt
import math
x=list(range(1,1000))
plt.plot(x,[math.log(y,2) for y in x]) #O(log n)
plt.plot(x,[y for y in x])  #O(n)
plt.plot(x,[y*math.log(y,2) for y in x]) #O(n log n)
